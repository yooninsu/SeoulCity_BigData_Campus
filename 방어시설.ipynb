# %%
import pandas as pd
import sklearn.tree as sktree
import scipy as sp
import os
path = "./데이터/"
filename = os.listdir(path)

# %%
하수관거 = pd.read_csv(f"{path}하수관거_20231114144851.csv")
빗물저류시설 = pd.read_excel(f"{path}빗물저류시설유지관리시설현황_2030하수도정비기본계획_2015.xlsx")
빗물펌프장 = pd.read_excel(f"{path}빗물펌프장_2030하수도정비기본계획_2015.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\yis82\OneDrive\Desktop\서울시\방어시설.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EB%B0%A9%EC%96%B4%EC%8B%9C%EC%84%A4.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> 하수관거 = pd.read_csv(f"{path}하수관거_20231114144851.csv")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EB%B0%A9%EC%96%B4%EC%8B%9C%EC%84%A4.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> 빗물저류시설 = pd.read_excel(f"{path}빗물저류시설유지관리시설현황_2030하수도정비기본계획_2015.xlsx")
#       <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EB%B0%A9%EC%96%B4%EC%8B%9C%EC%84%A4.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> 빗물펌프장 = pd.read_excel(f"{path}빗물펌프장_2030하수도정비기본계획_2015.xlsx")
#
# ...

# %%
하수관거
# Out:
#     자치구별(1)  자치구별(2)      2021    2021.1   2021.2    2021.3   2021.4   2021.5  \
# 0   자치구별(1)  자치구별(2)  계획연장 (m)  시설연장 (m)  보급율 (%)   합류식 (m)  합류식 (m)  합류식 (m)
# 1   자치구별(1)  자치구별(2)        소계        소계       소계  계획면적 (㎢)     계획연장     시설연장
# 2   자치구별(1)  자치구별(2)        소계        소계       소계        소계       소계       소계
# 3        합계       소계  10844239  10827521      100     342.3  9514478  9505253
# 4        합계      종로구    364119    364119      100      14.1   340876   340876
# 5        합계       중구    272011    272011      100       9.9   264888   264888
# 6        합계      용산구    373484    373331      100      17.0   354954   354954
# 7        합계      성동구    306078    305936      100      12.7   296825   296825
# 8        합계      광진구    363986    363986      100      11.6   358354   358354
# 9        합계     동대문구    407967    407880      100      11.7   401444   401444
# 10       합계      중랑구    429297    429297      100      11.4   404608   404608
# ...
