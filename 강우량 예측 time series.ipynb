# %%
from dbfread import DBF
import os
import sys
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from tabulate import tabulate
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.seasonal import STL


plt.rcParams["font.family"] = 'AppleGothic' if sys.platform == 'darwin' else 'Malgun Gothic'
plt.rcParams["font.size"] = 12
plt.rcParams["axes.unicode_minus"] = False

# %%
os.getcwd()
# Out:
# 'c:\\Users\\yis82\\OneDrive\\Desktop\\Project\\서울시'

# %%
df = DBF('./데이터\\B422. 서울시 누적강수량(월평균) 공간데이터\\2. 파일데이터\\2019\\TL_RFL_AGE_2019.dbf',encoding='euc-kr', load=True)
dbf = pd.DataFrame(df)
dbf
# Out:
#      M01   M02   M03   M04   M05   M06   M07   M08   M09   M10  ...  \
# 0    1.0  33.0  19.5  28.0  39.0  48.5  1.96  1.02  26.0  20.0  ...
# 1    0.5  27.5  18.0  39.5  32.0  47.5  1.97  1.00  25.0  19.0  ...
# 2    0.0   1.0  20.0  32.5  37.5  55.5  1.95  1.14  33.5  20.5  ...
# 3    0.0  46.5  22.0  37.5  33.5  57.0  2.16  1.15  18.0  22.5  ...
# 4    0.5  31.5  14.5  19.5  36.0  44.0  1.82  1.16  25.0  19.0  ...
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 516  0.0   1.5   1.2   1.6   1.0   2.5  9.00  6.30   4.3   3.4  ...
# 517  0.0   1.2   1.0   1.3   0.9   2.6  6.30  6.00   6.5   2.6  ...
# 518  0.0   1.2   0.9   1.6   1.4   2.1  8.90  6.40   4.6   2.9  ...
# 519  0.0   1.7   1.4   1.6   1.0   2.7  8.70  6.30   5.3   4.0  ...
# 520  0.0   1.4   0.9   1.3   1.1   2.7  7.90  7.70   6.0   3.8  ...
#
#                      ADDR_KOR            DGE_X             DGE_Y DAMDANG  \
# 0     중구 삼일대로 231(예장동 산 5-85)  N 37°33' 21.13"  E 126°59' 31.57"     서울시
# 1       동대문구 한천로 326(휘경동 348)  N 37°35' 20.58"  E 127°04' 11.28"     서울시
# 2       성북구 종암로 98-8(종암동주민센터)  N 37°35' 56.62"  E 127°02' 06.73"     서울시
# 3        도봉구 해등로 25(창동 362-1)  N 37°40' 07.93"  E 127°02' 35.15"     서울시
# 4         마포구 성중길 82(성산동 445)  N 37°34' 25.43"  E 126°54' 02.53"     서울시
# ..                        ...              ...               ...     ...
# 516        성동구 서울숲길 18(성수중학교)  N 37°32' 41.99"  E 127°02' 26.17"     기상청
# 517       구로구 부일로 893(온수초등학교)  N 37°28' 59.88"  E 126°49' 59.87"     기상청
# 518       강북구 도봉로89길 13(강북구청)  N 37°37' 59.88"  E 127°00' 06.12"     기상청
# 519  서울특별시 관악구 남현동 사서함 20003호  N 37°27' 46.80"  E 126°59' 09.60"     기상청
# 520  관악구 관악로 1(서울대학교 대기환경관측소)  N 37°27' 00.36"  E 126°57' 08.28"     기상청
#
#                         CONTENT     MK_YEAR                      ETC  \
# 0    풍향/풍속/기온/강수량/강수유무/습도/일사/일조  2009-01-08            서울시청 남산별관(4층)
# 1          풍향/풍속/기온/강수량/강수유무/습도  2009-01-09            휘경 빗물 펌프장(2층)
# 2          풍향/풍속/기온/강수량/강수유무/습도  2009-01-08  종암동주민센터(5층)//3.15이설완료//
# 3          풍향/풍속/기온/강수량/강수유무/습도  2009-01-07    도봉소방서(창동 119안전센터)(2층)
# 4          풍향/풍속/기온/강수량/강수유무/습도  2009-01-09              성산빗물펌프장(2층)
# ..                          ...         ...                      ...
# 516        풍향/풍속/기온/강수량/강수유무/습도        2008                  기상청 관측소
# 517        풍향/풍속/기온/강수량/강수유무/습도        2008                  기상청 관측소
# 518        풍향/풍속/기온/강수량/강수유무/습도        2008                  기상청 관측소
# 519        풍향/풍속/기온/강수량/강수유무/습도  2013-02-18
# 520        풍향/풍속/기온/강수량/강수유무/습도        2008                  기상청 관측소
#
#         MTHD_NM     CMDT_NM   SOURCETHM
# 0    199302.289  550710.248  07(일누적강수량)
# 1    206164.021  554394.772  07(일누적강수량)
# 2    203108.332  555504.066  07(일누적강수량)
# 3    203801.837  563251.524  07(일누적강수량)
# 4    191229.289  552697.015  07(일누적강수량)
# ..          ...         ...         ...
# 516  203588.239  549499.131  07(일누적강수량)
# 517  185255.990  542663.612  07(일누적강수량)
# 518  200150.175  559298.951  07(일누적강수량)
# 519  198761.439  540397.847  07(일누적강수량)
# 520  195779.392  538966.956  07(일누적강수량)
#
# [521 rows x 25 columns]

# %%
stationarity = False

# %%
for i in range(1, 13):
    column_name = f'M0{i}' if i < 10 else f'M{i}'  
    missing_count = dbf[column_name].isna().sum()
    print(f'Column {column_name}: {missing_count} missing values')
# Out:
# Column M01: 0 missing values
# Column M02: 0 missing values
# Column M03: 0 missing values
# Column M04: 0 missing values
# Column M05: 0 missing values
# Column M06: 0 missing values
# Column M07: 0 missing values
# Column M08: 0 missing values
# Column M09: 0 missing values
# Column M10: 0 missing values
# Column M11: 0 missing values
# Column M12: 0 missing values

# %%
col_name = []
for i in range(1, 13):
    column_name = f'M0{i}' if i < 10 else f'M{i}'  
    missing_count = dbf[column_name].fillna(1, inplace= True)
    col_name.append(column_name)

# %%
condition = dbf['NAME'] == '[기]서울'

# %%
seoul_df = dbf[condition]
seoul_df
# Out:
#       M01   M02   M03   M04   M05    M06     M07     M08    M09   M10  ...  \
# 25    0.0   0.0  19.5  38.5  38.0   48.5    1.90    1.13   30.5  19.5  ...
# 94    4.0   0.0  22.0  47.5   6.5   69.5    1.02    1.37   85.5  44.0  ...
# 168  14.5  26.5  17.0  27.0  59.0   71.0   89.50   99.00  259.5  15.0  ...
# 226   3.5  28.5   5.5  69.0  15.0  177.0    3.02   41.50   22.5  20.0  ...
# 261   4.0  10.5   5.5  28.0  14.0   44.5   80.00   29.00   18.5  35.5  ...
# 318   3.5   4.0  19.5  37.5   6.0   29.0  144.50  124.50   24.0  20.0  ...
# 335  16.5  46.5  11.5  21.0  56.5   12.0    1.65   45.00   50.0   6.5  ...
# 393   6.0  11.0   1.5  13.5  11.0   33.0   20.50   46.50   57.5  21.5  ...
# 465   0.0  25.0  27.0  18.5  83.0   71.5   83.50   96.50   34.5  55.5  ...
# 495   0.0   1.0   0.9   1.6   1.2    2.5    6.50    6.10    4.7   3.8  ...
#
#                 ADDR_KOR            DGE_X             DGE_Y DAMDANG  \
# 25   종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 94   종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 168  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 226  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 261  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 318  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 335  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 393  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 465  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
# 495  종로구 송월길 52(서울기상관측소)  N 37°34' 17.00"  E 126°57' 56.16"     기상청
#
#                   CONTENT MK_YEAR      ETC     MTHD_NM     CMDT_NM   SOURCETHM
# 25   풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 94   풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 168  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 226  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 261  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 318  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 335  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 393  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 465  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196961.427  552433.066  07(일누적강수량)
# 495  풍향/풍속/기온/강수량/강수유무/습도    2008  기상청 관측소  196960.980  552427.898  07(일누적강수량)
#
# [10 rows x 25 columns]

# %%
melt_df = pd.melt(seoul_df[col_name])
melt_df
# Out:
#     variable  value
# 0        M01    0.0
# 1        M01    4.0
# 2        M01   14.5
# 3        M01    3.5
# 4        M01    4.0
# ..       ...    ...
# 115      M12   20.0
# 116      M12   14.0
# 117      M12   10.0
# 118      M12    0.0
# 119      M12    0.0
#
# [120 rows x 2 columns]

# %%
test_df = melt_df.drop('variable', axis = 1)

# %%
start_date = '2010-01-01'
end_date = '2020-01-01'
monthly_index = pd.date_range(start=start_date, end=end_date, freq='M')

# Extract and format only the months and years
formatted_index = monthly_index.strftime('%Y-%m-%d')

# %%
plt.rcParams["figure.figsize"] = (40, 10)
sb.lineplot(data = test_df, x = formatted_index,  y = 'value')
plt.xticks(rotation= 45)
plt.show()
plt.close()

# %%
formatted_index
# Out:
# Index(['2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30', '2010-05-31',
#        '2010-06-30', '2010-07-31', '2010-08-31', '2010-09-30', '2010-10-31',
#        ...
#        '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
#        '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31'],
#       dtype='object', length=120)

# %%
temp_test_df=test_df.set_index(formatted_index)
temp_test_df
# Out:
#             value
# 2010-01-31    0.0
# 2010-02-28    4.0
# 2010-03-31   14.5
# 2010-04-30    3.5
# 2010-05-31    4.0
# ...           ...
# 2019-08-31   20.0
# 2019-09-30   14.0
# 2019-10-31   10.0
# 2019-11-30    0.0
# 2019-12-31    0.0
#
# [120 rows x 1 columns]

# %%
rainfall = pd.Series(data = test_df['value'], index = formatted_index)
rainfall
# Out:
# 2010-01-31   NaN
# 2010-02-28   NaN
# 2010-03-31   NaN
# 2010-04-30   NaN
# 2010-05-31   NaN
#               ..
# 2019-08-31   NaN
# 2019-09-30   NaN
# 2019-10-31   NaN
# 2019-11-30   NaN
# 2019-12-31   NaN
# Name: value, Length: 120, dtype: float64

# %%
from statsmodels.tsa.seasonal import STL
# test
stl = STL(temp_test_df['value'],seasonal=13)
# Fit the decomposition
result = stl.fit()
# Plot the decomposed components
fig = result.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\yis82\OneDrive\Desktop\Project\서울시\강우량 예측 time series.ipynb Cell 17 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/Project/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EA%B0%95%EC%9A%B0%EB%9F%89%20%EC%98%88%EC%B8%A1%20time%20series.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> from statsmodels.tsa.seasonal import STL
#       <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/Project/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EA%B0%95%EC%9A%B0%EB%9F%89%20%EC%98%88%EC%B8%A1%20time%20series.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> # test
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/Project/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EA%B0%95%EC%9A%B0%EB%9F%89%20%EC%98%88%EC%B8%A1%20time%20series.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> stl = STL(temp_test_df['value'],seasonal=13)
#       <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/Project/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EA%B0%95%EC%9A%B0%EB%9F%89%20%EC%98%88%EC%B8%A1%20time%20series.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> # Fit the decomposition
#       <a href='vscode-notebook-cell:/c%3A/Users/yis82/OneDrive/Desktop/Project/%EC%84%9C%EC%9A%B8%EC%8B%9C/%EA%B0%95%EC%9A%B0%EB%9F%89%20%EC%98%88%EC%B8%A1%20time%20series.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> result = stl.fit()
#
# File statsmodels\tsa\stl\_stl.pyx:220, in statsmodels.tsa.stl._stl.STL.__init__()
#
# ValueError: Unable to determine period from endog

# %%
import pandas as pd

# Create a sample DataFrame
data = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}

df = pd.DataFrame(data)

# Convert a specific column to a Series
series_from_column = df['A']

# series_from_column is now a pandas Series
print(series_from_column)
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
rainfall = pd.Series(melt_df['value'])
rainfall.name
# Out:
# 'value'

# %%
sd = seasonal_decompose(rainfall, model='additive', period=12)
figure = sd.plot()
figure.set_figwidth(15)
figure.set_figheight(16)
fig, ax1, ax2, ax3, ax4 = figure.get_children()
figure.subplots_adjust(hspace=0.4)
ax1.set_ylabel("Observed")
ax1.grid(True)
ax1.title.set_text("Original")
ax2.grid(True)
ax2.title.set_text("Trend")
ax3.grid(True)
ax3.title.set_text("Seasonal")
ax4.grid(True)
ax4.title.set_text("Residual")
plt.show()

# %%
# ACF, PACF 검정
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))
fig.subplots_adjust(hspace=0.4)

plot_acf(melt_df['value'], ax=ax1)
ax2.title.set_text("ACF Test")
    
plot_pacf(melt_df['value'], ax=ax2)
ax3.title.set_text("PACF Test")
    
plt.show()
plt.close()

# %%
ar = adfuller(melt_df['value'])
ardict = {
        '검정통계량(ADF Statistic)': [ar[0]],
        '유의수준(p-value)': [ar[1]],
        '최적차수(num of lags)': [ar[2]],
        '관측치 개수(num of observations)': [ar[3]]   
    }

for key, value in ar[4].items():
    ardict['기각값(Critical Values) %s' % key] = value

stationarity = ar[1] < 0.05
ardict['데이터 정상성 여부(0=Flase,1=True)'] = stationarity

ardf = DataFrame(ardict, index=['ADF Test']).T

print(tabulate(ardf, headers=["ADF Test", ""], tablefmt='psql', numalign="right"))
# Out:
# +------------------------------------+-------------+
# | ADF Test                           |             |
# |------------------------------------+-------------|
# | 검정통계량(ADF Statistic)          |    -9.00877 |
# | 유의수준(p-value)                  | 6.20748e-15 |
# | 최적차수(num of lags)              |           0 |
# | 관측치 개수(num of observations)   |         119 |
# | 기각값(Critical Values) 1%         |    -3.48653 |
# | 기각값(Critical Values) 5%         |    -2.88615 |
# | 기각값(Critical Values) 10%        |     -2.5799 |
# | 데이터 정상성 여부(0=Flase,1=True) |           1 |
# +------------------------------------+-------------+

# %%
model = ARIMA(melt_df['value'], order=(3,1,3), seasonal_order=(3,1,3,12))
fit = model.fit()
print(fit.summary())
# Out:
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:559: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _index = to_datetime(index)
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:559: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _index = to_datetime(index)
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:559: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _index = to_datetime(index)
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                     SARIMAX Results
# ========================================================================================
# Dep. Variable:                            value   No. Observations:                  120
# Model:             ARIMA(3, 1, 3)x(3, 1, 3, 12)   Log Likelihood                -549.793
# Date:                          Wed, 04 Oct 2023   AIC                           1125.587
# Time:                                  11:36:19   BIC                           1160.333
# Sample:                                       0   HQIC                          1139.673
#                                           - 120
# Covariance Type:                            opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3135      0.255     -5.149      0.000      -1.813      -0.814
# ar.L2         -0.9824      0.242     -4.052      0.000      -1.458      -0.507
# ar.L3         -0.0050      0.148     -0.034      0.973      -0.295       0.285
# ma.L1          0.4675      0.629      0.743      0.458      -0.766       1.701
# ma.L2         -0.1715      0.428     -0.401      0.689      -1.010       0.667
# ma.L3         -0.8674      0.868     -0.999      0.318      -2.569       0.834
# ar.S.L12      -0.9851     76.879     -0.013      0.990    -151.665     149.694
# ar.S.L24      -0.4077     38.474     -0.011      0.992     -75.815      75.000
# ar.S.L36      -0.0027      1.394     -0.002      0.998      -2.735       2.729
# ma.S.L12      -0.0258     72.047     -0.000      1.000    -141.235     141.183
# ma.S.L24      -0.5455     46.919     -0.012      0.991     -92.505      91.414
# ma.S.L36      -0.4037     38.812     -0.010      0.992     -76.475      75.667
# sigma2      1314.3446   1.03e+04      0.128      0.899   -1.89e+04    2.15e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):               306.31
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.26   Skew:                             1.98
# Prob(H) (two-sided):                  0.02   Kurtosis:                        10.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fv = fit.fittedvalues

# %%
fc = fit.forecast(156, method= 'naive')
fc
# Out:
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\yis82\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['method']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)
# 120    14.243782
# 121    -3.324378
# 122    17.410211
# 123    14.403377
# 124    19.016014
#          ...
# 271    10.783906
# 272    12.471291
# 273    16.481790
# 274    37.285815
# 275     0.320982
# Name: predicted_mean, Length: 156, dtype: float64

# %%
plt.figure(figsize=(20,8))
sb.lineplot(data=melt_df, x=formatted_index,  y='value', label='Original')
sb.lineplot(x=fv.index, y=fv.values, label='FittedValues', linestyle='--')
sb.lineplot(x=fc.index, y=fc.values, label='Predict', linestyle='--', color='red')

plt.xlabel('date')
plt.ylabel('ratio')
plt.legend()


plt.grid()
plt.show()
plt.close()
